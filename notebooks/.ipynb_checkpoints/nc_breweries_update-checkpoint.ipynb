# %%
import pandas as pd

# %%
nc_breweries_df = pd.read_csv("../data/nc_breweries_df.csv")

# %%
nc_breweries_df
# Out:
#      Unnamed: 0 brewery_id                    breweries in_business  \
# 0             0     QEB46N              7 Clans Brewing           Y
# 1             1     ichhfQ         Olde Hickory Brewery           Y
# 2             2     SYkdNz      Andrews Brewing Company           Y
# 3             3     Cwhr9F    Archetype Brewing Company           Y
# 4             4     nHLlnK    Sierra Nevada Brewing Co.           Y
# ..          ...        ...                          ...         ...
# 254         363     EeNu7g        UpCountry Brewing Co.           Y
# 255         364     bxzsq8       Uptown Brewing Company           Y
# 256         365     pEl3VV       Vicious Fishes Brewery           Y
# 257         366     yO2ogr        Wedge Brewing Company           Y
# 258         367     zeWbuM  Wicked Weed Brewing Company           Y
#
#            city           state   latitude  longitude          brewery_type  \
# ...

# %%
nc_breweries_df = nc_breweries_df.fillna("Not Available")

# %%
nc_breweries_df.to_csv("../data/nc_breweries_df.csv", index=False)
