# %%
import pandas as pd

# %%
# import data
beer_list_df = pd.read_csv("data/beer_list_df.csv")

# %%
# isolate beer_style
beer_style = beer_list_df["beer_style"]

# %%
master_style = []
style_type = ""

for style in beer_style:
    if style.endswith("India Pale Ale"):
        style_type = "IPA"
        master_style.append(style_type)
    elif style.endswith("Pale Ale"):
        style_type = "Pale Ale"
        master_style.append(style_type)
    elif style.endswith("Ale"):
        style_type = "Ale"
        master_style.append(style_type)
    elif style.endswith("Stout"):
        style_type = "Stout"
        master_style.append(style_type)
    elif style.endswith("Lager"):
        style_type = "Lager"
        master_style.append(style_type)
    elif style.endswith("Saison"):
        style_type = "Saison"
        master_style.append(style_type)
    elif style.endswith("Porter"):
        style_type = "Porter"
        master_style.append(style_type)
    elif style.endswith("Wheat Beer"):
        style_type = "Wheat Beer"
        master_style.append(style_type)
    elif style.endswith("Kolsch"):
        style_type = "Kolsch"
        master_style.append(style_type)
    elif style.endswith("Hefeweizen / Hefeweissbier"):
        style_type = "Hefeweizen"
        master_style.append(style_type)
    else:
        master_style.append("Other")
        
print(len(master_style))
# Out:
# 5697

# %%
beer_list_df["master_style"] = master_style

# %%
beer_list_df
# Out:
#       Unnamed: 0 brewery_id beer_id availability                 beer_name  \
# 0              0     QEB46N  rjwbiG   Year Round               Bended Tree
# 1              1     QEB46N  6NOE18   Year Round                Blonde Ale
# 2              2     QEB46N  U3fPrh   Year Round                Hop Rooted
# 3              3     ichhfQ  SgJVJf      Limited               Bee Student
# 4              4     ichhfQ  SlOBl2     Seasonal               Bestway IPA
# ...          ...        ...     ...          ...                       ...
# 5692        5692     pEl3VV  Zt5hEQ   Year Round           Here Be Dragons
# 5693        5693     pEl3VV  Qbg8cE   Year Round  Into the Abyss Brown Ale
# 5694        5694     pEl3VV  2vOwlf     Seasonal               Jolie Rouge
# 5695        5695     pEl3VV  ByEWJM   Year Round                  PlioSour
# 5696        5696     pEl3VV  fF7kv6     Seasonal       Siren's Song Saison
#
# ...

# %%
del beer_list_df["Unnamed: 0"]

# %%
beer_list_df.to_csv("data/beer_list_df.csv")
